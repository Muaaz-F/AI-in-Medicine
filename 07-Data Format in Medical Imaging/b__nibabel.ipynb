# %% [markdown]
# In this notebook you will learn how to work with medical image data stored in the NIfTI format.
#
# We will take a look at the nibabel python package which allows handling NIfTI files.
#
# In a first step, we will convert the DICOM data from the previous session to the NIfTI format and continue from there.

# %% [markdown]
# ## DICOM to NIfTI conversion
# It can be very useful to concert DICOM files to the NIftI format before further processing as NIfTI files are easier to handle. There are many tools, we will use dicom2nifti:

# %%
# !pip install dicom2nifti
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dicom2nifti
#   Obtaining dependency information for dicom2nifti from https://files.pythonhosted.org/packages/00/e5/37cc1e70676b9f7d6eb5aa148ef80827ae42f42276789a7b755e92af202b/dicom2nifti-2.5.0-py3-none-any.whl.metadata
#   Downloading dicom2nifti-2.5.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting nibabel (from dicom2nifti)
#   Obtaining dependency information for nibabel from https://files.pythonhosted.org/packages/8f/52/3057e5b0dcb88f472594c314201172f1c8386eace3255944096784a3d9dc/nibabel-5.3.1-py3-none-any.whl.metadata
#   Downloading nibabel-5.3.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from dicom2nifti) (1.24.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from dicom2nifti) (1.11.1)
# Requirement already satisfied: pydicom>=2.2.0 in c:\users\muaaz\appdata\roaming\python\python311\site-packages (from dicom2nifti) (3.0.1)
# Collecting python-gdcm (from dicom2nifti)
#   Obtaining dependency information for python-gdcm from https://files.pythonhosted.org/packages/69/c2/2ed227c59165809777d2360a539986b36a9c332637e02fc991364fc07312/python_gdcm-3.0.24.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading python_gdcm-3.0.24.1-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Collecting importlib-resources>=5.12 (from nibabel->dicom2nifti)
#   Obtaining dependency information for importlib-resources>=5.12 from https://files.pythonhosted.org/packages/e1/6a/4604f9ae2fa62ef47b9de2fa5ad599589d28c9fd1d335f32759813dfa91e/importlib_resources-6.4.5-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: packaging>=20 in c:\programdata\anaconda3\lib\site-packages (from nibabel->dicom2nifti) (23.1)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\muaaz\appdata\roaming\python\python311\site-packages (from nibabel->dicom2nifti) (4.12.2)
# Downloading dicom2nifti-2.5.0-py3-none-any.whl (43 kB)
#    ---------------------------------------- 0.0/43.6 kB ? eta -:--:--
#    ------------------------------------- -- 41.0/43.6 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 43.6/43.6 kB 1.0 MB/s eta 0:00:00
# Downloading nibabel-5.3.1-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.3 MB 9.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.8/3.3 MB 10.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.4/3.3 MB 11.0 MB/s eta 0:00:01
#    ------------------------- -------------- 2.1/3.3 MB 13.2 MB/s eta 0:00:01
#    ------------------------------------ --- 3.0/3.3 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 13.1 MB/s eta 0:00:00
# Downloading python_gdcm-3.0.24.1-cp311-cp311-win_amd64.whl (28.9 MB)
#    ---------------------------------------- 0.0/28.9 MB ? eta -:--:--
#    - -------------------------------------- 0.9/28.9 MB 29.1 MB/s eta 0:00:01
#    -- ------------------------------------- 1.6/28.9 MB 26.4 MB/s eta 0:00:02
#    --- ------------------------------------ 2.5/28.9 MB 22.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 3.1/28.9 MB 25.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 3.1/28.9 MB 25.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 3.2/28.9 MB 13.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 4.2/28.9 MB 14.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 4.2/28.9 MB 14.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 4.2/28.9 MB 14.9 MB/s eta 0:00:02
#    ------ --------------------------------- 4.9/28.9 MB 12.1 MB/s eta 0:00:02
#    ------- -------------------------------- 5.7/28.9 MB 12.6 MB/s eta 0:00:02
#    --------- ------------------------------ 7.0/28.9 MB 14.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 8.2/28.9 MB 14.9 MB/s eta 0:00:02
#    ------------- -------------------------- 9.4/28.9 MB 15.8 MB/s eta 0:00:02
#    -------------- ------------------------- 10.5/28.9 MB 16.4 MB/s eta 0:00:02
#    -------------- ------------------------- 10.5/28.9 MB 16.0 MB/s eta 0:00:02
#    -------------- ------------------------- 10.6/28.9 MB 14.2 MB/s eta 0:00:02
#    --------------- ------------------------ 11.5/28.9 MB 14.6 MB/s eta 0:00:02
#    --------------- ------------------------ 11.5/28.9 MB 14.6 MB/s eta 0:00:02
#    --------------- ------------------------ 11.5/28.9 MB 14.6 MB/s eta 0:00:02
#    --------------- ------------------------ 11.5/28.9 MB 14.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 12.2/28.9 MB 12.1 MB/s eta 0:00:02
#    ------------------ --------------------- 13.1/28.9 MB 11.9 MB/s eta 0:00:02
#    ------------------- -------------------- 14.0/28.9 MB 13.4 MB/s eta 0:00:02
#    --------------------- ------------------ 15.2/28.9 MB 16.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 16.0/28.9 MB 15.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 17.2/28.9 MB 15.6 MB/s eta 0:00:01
#    ------------------------- -------------- 18.4/28.9 MB 15.6 MB/s eta 0:00:01
#    -------------------------- ------------- 19.1/28.9 MB 14.9 MB/s eta 0:00:01
#    --------------------------- ------------ 20.1/28.9 MB 15.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 21.3/28.9 MB 17.2 MB/s eta 0:00:01
#    ------------------------------ --------- 22.3/28.9 MB 23.4 MB/s eta 0:00:01
#    -------------------------------- ------- 23.5/28.9 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 24.9/28.9 MB 24.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 25.8/28.9 MB 25.2 MB/s eta 0:00:01
#    ------------------------------------- -- 26.9/28.9 MB 25.2 MB/s eta 0:00:01
#    -------------------------------------- - 27.8/28.9 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------  28.5/28.9 MB 24.2 MB/s eta 0:00:01
#    ---------------------------------------  28.9/28.9 MB 24.3 MB/s eta 0:00:01
#    ---------------------------------------  28.9/28.9 MB 24.3 MB/s eta 0:00:01
#    ---------------------------------------- 28.9/28.9 MB 18.7 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Installing collected packages: python-gdcm, importlib-resources, nibabel, dicom2nifti
# Successfully installed dicom2nifti-2.5.0 importlib-resources-6.4.5 nibabel-5.3.1 python-gdcm-3.0.24.1
#   WARNING: The scripts gdcmanon.exe, gdcmconv.exe, gdcmdiff.exe, gdcmdump.exe, gdcmgendir.exe, gdcmimg.exe, gdcminfo.exe, gdcmpap3.exe, gdcmraw.exe, gdcmscanner.exe, gdcmscu.exe, gdcmtar.exe and gdcmxml.exe are installed in 'C:\Users\muaaz\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts nib-conform.exe, nib-convert.exe, nib-dicomfs.exe, nib-diff.exe, nib-ls.exe, nib-nifti-dx.exe, nib-roi.exe, nib-stats.exe, nib-tck2trk.exe, nib-trk2tck.exe and parrec2nii.exe are installed in 'C:\Users\muaaz\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import dicom2nifti
from pathlib import Path

# %% [markdown]
# In order to demonstrate DICOM to NIfTI conversion we will use the DICOM data set downloaded in the last lecture on  DICOM data.

# %% [markdown]
# Check your folder. Do you see any file with this name `201_t2w_tse.nii.gz`

# %%
path_to_dicom = "SE000001"

# %%
dicom2nifti.convert_directory(path_to_dicom, ".")

# %% [markdown]
# You will now find the file *201_t2w_tse.nii.gz* in the *path_to_nifti* (have a look)

# %% [markdown]
# ## Read NIfTI files
#
# Now, we proceed to the process of reading and exploring NIfTI files
#
# First we import the necessary packages
#
# ## Imports
#
# * nibabel to handle nifti files
# * matplotlib to plot the brain images

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# %% [markdown]
# This single NIfTI file created above contains the complete 3D mri scan! <br />
# We can load it by using *nib.load(path)*

# %%
nifti = nib.load('201_t2w_tse.nii.gz')

# %% [markdown]
# You can print this object in order to look at metadata including the NIftI **header** information:

# %%
print(nifti)
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (256, 256, 27)
# affine:
# [[-9.36898887e-01  3.20514254e-02  6.37919828e-02  1.15272324e+02]
#  [ 3.03588901e-02  9.27917123e-01 -8.33337128e-01 -9.72956390e+01]
#  [ 1.43172191e-02  1.29802674e-01  5.94150448e+00 -8.23735046e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b''
# dim_info        : 0
# dim             : [  3 256 256  27   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : uint16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.         0.9375     0.9375     5.9999995  1.         1.
#   1.         1.       ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 2
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : unknown
# sform_code      : aligned
# quatern_b       : -0.016685799
# quatern_c       : -0.9974202
# quatern_d       : -0.069515765
# qoffset_x       : 115.27232
# qoffset_y       : -97.29564
# qoffset_z       : -82.373505
# srow_x          : [-9.3689889e-01  3.2051425e-02  6.3791983e-02  1.1527232e+02]
# srow_y          : [ 3.035889e-02  9.279171e-01 -8.333371e-01 -9.729564e+01]
# srow_z          : [ 1.4317219e-02  1.2980267e-01  5.9415045e+00 -8.2373505e+01]
# intent_name     : b''
# magic           : b'n+1'

# %% [markdown]
# You can access single header entries in the following simple way:

# %% [markdown]
# You can access single metadata entries as follows:

# %%
import numpy as np

# %%
nifti.header["qoffset_x"]
# Out:
# array(115.27232, dtype=float32)

# %%
print(nifti.shape) # get the image shape
print(nifti.header.get_data_shape()) # get the image shape in a different way
# Out:
# (256, 256, 27)
# (256, 256, 27)

# %% [markdown]
# Obtaining image **pixel data**:
#
# The image pixel data can be extracted using the *get_fdata()* function of the nifti object.

# %%
image_array = nifti.get_fdata(dtype = np.float32)
print(image_array.dtype, image_array.shape)
# Out:
# float32 (256, 256, 27)

# %% [markdown]
# We can finally take a look at the brain scan. <br />
#
# Don't forget to pass cmap="gray" to imshow, otherwise your image will look quite odd

# %%
fig, axis = plt.subplots(3, 3, figsize=(10, 10))

slice_counter = 0
for i in range(3):
    for j in range(3):
        axis[i][j].imshow(image_array[:,:,slice_counter], cmap="gray")
        slice_counter+=1

# %% [markdown]
# ### Write NIfTI files
# Manytimes, you will obtain image data as the results of an algorithm or processing step that you want to store in the NIfTI format. This can be easily done using NiBabel. As an example, We use the 3D image array from above, perform a simple processing step and save it as a new NIfTI file.

# %%
# Here we apply a very simple threshold and set all image voxels to 0 that have a value smaller than 300
image_array_processed = image_array * (image_array>300)

# %%
# Now let us look at the results of this processing step (we just plot slice number 13) 
plt.imshow(image_array[:,:,13],cmap="gray") # plot the original image
plt.axis("off")
plt.figure()
plt.imshow(image_array_processed[:,:,13],cmap="gray") # plot the processed image
plt.axis("off")
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# First we convert the processed image array back to a nifti object. To this end we use the numpy array of the processed image and header information about the image geometry (affine matrix) from the original NIftI file:

# %%
processed_nifti = nib.Nifti1Image(image_array_processed, nifti.affine)

# %% [markdown]
# We can now save the processed image using the save function in NiBabel:

# %%
nib.save(processed_nifti, '201_t2w_tse_processed.nii.gz')

# %% [markdown]
# Now, check your folder!

# %% [markdown]
# ----------
